# %%
# text retrieval

# %%
import requests
from bs4 import BeautifulSoup

# %%
pageUrl = "https://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/"

# %%
page = requests.get(pageUrl)

# %%
parsed_page = BeautifulSoup(page.text, 'lxml')

# %%
print(parsed_page)
# Out:
# <!DOCTYPE html>
# <html lang="en-us">
# <head>
# <title>This Game of Thrones climate model is what’s been missing from your life | Ars Technica</title>
# <script type="text/javascript">
#     ars = {"ASSETS":"https:\/\/cdn.arstechnica.net\/wp-content\/themes\/ars\/assets","HOME_URL":"https:\/\/arstechnica.com","LOGIN_URL":"https:\/\/arstechnica.com\/services\/login-desktop.html?v=1","CIVIS":"\/civis","THEME":"light","VIEW":"grid","MOBILE":false,"PREMIER":false,"LOGGED":false,"ENV":"production","AD":{"kw":["section_science","discipline","earth-science-2","science","culture"],"zone":"culture","queue":[]},"TOTAL":85237,"UNREAD":0,"RECENT":[1235341,1234151,1236117,1237041,1236977,1236817,1236905,1236917,1236863,1213093,1236821,1236811,1236721,1236723,1236671,1236445,1233429,1236479,1236441,1236661,1236459,1236439,1236461,1236281,1236021],"LOGINS":true,"CROSS":false,"PARSELY":"arstechnica.com","COMMENTS":false,"HOMEPAGE":false,"SITE":1,"READY":[],"SHOW_ADS":true,"IMG_PROXY":"https:\/\/cdn.arstechnica.net\/i\/","CATEGORY":"science","PAGETITLE":""};
#   </script>
# <link href="https://cdn.arstechnica.net/wp-content/themes/ars/assets/css/main-9f463a2642.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://feeds.arstechnica.com/arstechnica/index/" rel="alternate" type="application/rss+xml"/>
# <link href="https://cdn.arstechnica.net/favicon.ico" rel="shortcut icon"/>
# <link href="https://cdn.arstechnica.net/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://cdn.arstechnica.net/wp-content/themes/ars/assets/img/ars-ios-icon-d9a45f558c.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://cdn.arstechnica.net/wp-content/themes/ars/assets/img/material-ars-db41652381.png" rel="icon" sizes="192x192"/>
# <meta content="Ars Technica" name="application-name"/>
# <meta content="http://arstechnica.com/" name="msapplication-starturl"/>
# <meta content="Ars Technica: Serving the technologist for 1.2 decades" name="msapplication-tooltip"/>
# <meta content="name=News;action-uri=http://arstechnica.com/;icon-uri=https://cdn.arstechnica.net/favicon.ico" name="msapplication-task"/>
# <meta content="name=Features;action-uri=http://arstechnica.com/features/;icon-uri=https://cdn.arstechnica.net/ie-jump-menu/jump-features.ico" name="msapplication-task"/>
# <meta content="name=OpenForum;action-uri=http://arstechnica.com/civis/;icon-uri=https://cdn.arstechnica.net/ie-jump-menu/jump-forum.ico" name="msapplication-task"/>
# <meta content="name=Subscribe;action-uri=http://arstechnica.com/subscriptions/;icon-uri=https://cdn.arstechnica.net/ie-jump-menu/jump-subscribe.ico" name="msapplication-task"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="ask" name="advertising"/>
# <meta content="592156917" property="fb:admins"/>
# <meta content="108943" property="fb:admins"/>
# <meta content="19374573752" property="fb:pages"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="#000000" name="theme-color"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <!-- cache miss 158:single/meta:42f36c5a4009c4b36e6fe08349345cea -->
# <meta content='{"title":"This Game of Thrones climate model is what\u2019s been missing from your life","link":"https:\/\/arstechnica.com\/science\/2017\/12\/there-is-now-a-climate-model-of-the-world-of-game-of-thrones\/","type":"post","author":"Scott K. Johnson","post_id":1236459,"pub_date":"2017-12-21T23:19:35Z","section":"Science","tags":["climate-model","type: report"],"image_url":"https:\/\/cdn.arstechnica.net\/wp-content\/uploads\/2017\/12\/game_of_thrones_climate_model-3-150x150.jpg"}' name="parsely-page"/>
# <meta content='{"type":"report","title":"This Game of Thrones climate model is what\u2019s been missing from your life","post_id":1236459,"lower_deck":"\u201cSamwell Tarly\u2019s\u201d tongue-in-cheek paper takes a swing at why winter is coming.","image_url":"https:\/\/cdn.arstechnica.net\/wp-content\/uploads\/2017\/12\/game_of_thrones_climate_model-3-150x150.jpg","listing_image_url":"https:\/\/cdn.arstechnica.net\/wp-content\/uploads\/2017\/12\/game_of_thrones_climate_model-3-360x200.jpg"}' name="parsely-metadata"/>
# <link href="https://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/" rel="canonical"/>
# <link href="https://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/?amp=1" rel="amphtml"/>
# <link href="https://arstechnica.com/?p=1236459" rel="shorturl"/>
# <meta content="“Samwell Tarly’s” tongue-in-cheek paper takes a swing at why winter is coming." name="description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/" name="twitter:url"/>
# <meta content="This Game of Thrones climate model is what’s been missing from your life" name="twitter:title"/>
# <meta content="“Samwell Tarly’s” tongue-in-cheek paper takes a swing at why winter is coming." name="twitter:description"/>
# <meta content="@arstechnica" name="twitter:site"/>
# <meta content="arstechnica.com" name="twitter:domain"/>
# <meta content="Ars Technica" property="og:site_name"/>
# <meta content="https://cdn.arstechnica.net/wp-content/uploads/2017/12/game_of_thrones_climate_model-3-760x380.jpg" name="twitter:image:src"/>
# <meta content="760" name="twitter:image:width"/>
# <meta content="380" name="twitter:image:height"/>
# <meta content="@SJvatn" name="twitter:creator"/>
# <meta content="https://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/" property="og:url"/>
# <meta content="This Game of Thrones climate model is what’s been missing from your life" property="og:title"/>
# <meta content="https://cdn.arstechnica.net/wp-content/uploads/2017/12/game_of_thrones_climate_model-3-760x380.jpg" property="og:image"/>
# <meta content="“Samwell Tarly’s” tongue-in-cheek paper takes a swing at why winter is coming." property="og:description"/>
# <meta content="article" property="og:type"/>
# <script type="text/javascript">var digitalData = {"contributor":"Scott K. Johnson","contentID":1236459,"contentLength":1042,"display":"This Game of Thrones climate model is what\u2019s been missing from your life","pageType":"report","keywords":{"display":"climate-model|type: report"},"canonical":"https:\/\/arstechnica.com\/science\/2017\/12\/there-is-now-a-climate-model-of-the-world-of-game-of-thrones\/","pageValue":1,"publishDate":"2017-12-21T23:19:35+00:00","section":"Science"};</script>
# <!-- cache hit 158:single/header:42f36c5a4009c4b36e6fe08349345cea -->
# <script>
# !function(b,c,d){"use strict";var e=b.location.hostname,f=""!==b.location.port?":"+b.location.port:"",g=location.search.match(/CNS_SB=([^&\s]+)[&\s]?/)||[],h=e+f+"/cns"+(g.length?"-sandbox/"+g[1]:"")+"/services.min.js",i=d||"//"+h;b.cns=b.cns||{async:function(b,c){this.queue[b]||(this.queue[b]=[]),"function"==typeof c&&this.queue[b].push(c)},queue:{},embed:{backup:d}};var j;j=c.createElement("script"),j.async=!0,j.src=i,c.head.appendChild(j)}(window,document,'https://cdn.arstechnica.net/cns/services.min.js?1514107800');
# </script>
# </head>
# <body class="post-template-default single single-post postid-1236459 single-format-standard grid-view light blog-us">
# <aside class="ad ad_crown" id="ad_crown_top"></aside>
# <div class="site-wrapper">
# <header class="site-header">
# <div class="header-left">
# <a href="https://arstechnica.com" id="header-logo" title="Ars Technica Homepage">
# <span class="icon icon-logo-ars-us"></span>
# </a>
# <div class="dropdown" id="header-search">
# <a class="dropdown-toggle" href="/search/">
# <span class="icon icon-search-mag-glass"></span>
# </a>
# <div class="dropdown-content">
# <form action="/search/" id="search_form" method="GET">
# <input name="ie" type="hidden" value="UTF-8"/>
# <input id="hdr_search_input" name="q" placeholder="Search..." tabindex="10" type="text" value=""/>
# </form>
# <a class="nav-search-close">Close</a>
# </div>
# </div>
# <nav id="header-nav-primary">
# <ul>
# <li><a class="" href="/information-technology/">Biz &amp; IT</a></li>
# <li><a class="" href="/gadgets/">Tech</a></li>
# <li><a class="active" href="/science/">Science</a></li>
# <li><a class="" href="/tech-policy/">Policy</a></li>
# <li><a class="" href="/cars/">Cars</a></li>
# <li><a class="" href="/gaming/">Gaming &amp; Culture</a></li>
# <li><a href="/civis/">Forums</a></li> </ul>
# </nav>
# <div class="dropdown dropdown-mega" id="header-burger">
# <a class="dropdown-toggle" href="#site-footer">
# <span></span>
# </a>
# <div class="dropdown-content">
# <section class="burger-navigate">
# <h3>
# <span class="icon icon-half-target"></span>
#     Navigate
#   </h3>
# <ul>
# <li><a href="http://video.arstechnica.com/">Videos</a></li>
# <li><a href="/features/">Features</a></li>
# <li><a href="/reviews/">Reviews</a></li>
# <li><a href="/tag/ars-approved/">Ars Approved</a></li>
# </ul>
# <ul>
# <li><a href="/rss-feeds/">RSS Feeds</a></li>
# <li><a href="/?view=mobile">Mobile Site</a></li>
# </ul>
# <ul>
# <li><a href="/about-us/">About Ars</a></li>
# <li><a href="/staff-directory/">Staff Directory</a></li>
# <li><a href="/contact-us/">Contact Us</a></li>
# </ul>
# <ul>
# <li><a href="/advertise-with-us/">Advertise with Ars</a></li>
# <li><a href="/reprints/">Reprints</a></li>
# </ul>
# </section>
# <section class="burger-filter">
# <h3>
# <span class="icon icon-half-mag"></span>
#     Filter by topic
#   </h3>
# <ul id="burger-nav-primary">
# <li><a class="" href="/information-technology/">Biz &amp; IT</a></li>
# <li><a class="" href="/gadgets/">Tech</a></li>
# <li><a class="active" href="/science/">Science</a></li>
# <li><a class="" href="/tech-policy/">Policy</a></li>
# <li><a class="" href="/cars/">Cars</a></li>
# <li><a class="" href="/gaming/">Gaming &amp; Culture</a></li>
# <li><a href="/civis/">Forums</a></li> </ul>
# </section>
# <section class="burger-settings">
# <h3>
# <span class="icon icon-half-gear"></span>
#     Settings
#   </h3>
# <div>
# <div class="burger-layout">
# <p>Front page layout</p>
# <div class="burger-layout-grid">
# <a class="" href="http://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/?view=grid" rel="nofollow">
# <span class="icon icon-grid"></span><br/>
#     Grid
#     <div class="faux-radio active"></div>
# </a>
# </div>
# <div class="burger-layout-list">
# <a class="" href="http://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/?view=archive" rel="nofollow">
# <span class="icon icon-list"></span><br/>
#     List
#     <div class="faux-radio "></div>
# </a>
# </div>
# <div class="burger-layout-wide" style="display: none;">
# <a class="" href="http://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/?view=full" rel="nofollow">
# <span class="icon icon-wide"></span><br/>
#       Wide
#       <div class="faux-radio "></div>
# </a>
# </div>
# </div>
# <div class="burger-theme">
# <p>Site theme</p>
# <div class="burger-theme-light">
# <a class="" href="http://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/?theme=light" rel="nofollow">
# <span><span>Black on white</span></span>
# <div class="faux-radio active"></div>
# </a>
# </div>
# <div class="burger-theme-dark">
# <a class="" href="http://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/?theme=dark" rel="nofollow">
# <span><span>White on black</span></span>
# <div class="faux-radio "></div>
# </a>
# </div>
# </div>
# </div>
# </section>
# </div>
# </div>
# <a class="header-highlight-link" href="/store/">Store</a>
# <div class="dropdown dropdown-mega" id="header-account">
# <a class="dropdown-toggle" href="https://arstechnica.com/civis/ucp.php?mode=login&amp;return_to=%2Fscience%2F2017%2F12%2Fthere-is-now-a-climate-model-of-the-world-of-game-of-thrones%2F">
#       Sign in
#       <span class="icon dropdown-indicator icon-drop-indicator"></span>
# </a>
# <div class="dropdown-content">
# <section class="profile-activity">
# <h3>
# <span class="icon icon-half-bubble-up"></span>
#         Comment activity
#       </h3>
# <p>Sign up or login to join the discussions!</p>
# </section>
# <section class="profile-settings">
# <form action="https://arstechnica.com/civis/ucp.php?mode=login" id="login-form" method="post">
# <input id="username" name="username" placeholder="Username or Email" type="text"/>
# <input id="password" name="password" placeholder="Password" type="password"/>
# <input class="button button-orange button-wide" name="login" type="submit" value="Submit"/>
# <label id="remember-label">
# <input id="autologin" name="autologin" type="checkbox"/>
#   Stay logged in</label> <span>|</span> <a href="/civis/ucp.php?mode=sendpassword">Having trouble?</a>
# <input name="redirect" type="hidden" value="./ucp.php?mode=login&amp;return_to=%2Fservices%2Fx%2Fa.php%3Fpath%3D%2Fscience%2F2017%2F12%2Fthere-is-now-a-climate-model-of-the-world-of-game-of-thrones%2F%26s%3D1"/>
# <input name="return_to" type="hidden" value="/services/x/a.php?path=%2Fscience%2F2017%2F12%2Fthere-is-now-a-climate-model-of-the-world-of-game-of-thrones%2F&amp;s=1"/>
# </form>
# <div class="register-account">
# <span>Sign up to comment and more</span>
# <a class="signup-btn button button-wide" href="https://arstechnica.com/civis/ucp.php?mode=register">Sign up</a>
# </div>
# </section>
# </div>
# </div>
# </div>
# <div class="header-right">
# </div>
# </header>
# <div class="content-wrapper">
# <script type="text/javascript">
#   ars.ARTICLE = {"url":"https:\/\/arstechnica.com\/science\/2017\/12\/there-is-now-a-climate-model-of-the-world-of-game-of-thrones\/","short_url":"https:\/\/arstechnica.com\/?p=1236459","title":"This Game of Thrones climate model is what\u2019s been missing from your life","author":294205,"id":1236459,"topic":1413635,"pages":1,"current_page":1,"superscroll":false,"promoted":[],"single_page":false,"comments":64,"fullwidth":false,"slug":"there-is-now-a-climate-model-of-the-world-of-game-of-thrones","arsStaff":{"104481":{"name":"Aaron Zimmerman","title":"Copyeditor","staff":true},"520255":{"name":"Annalee Newitz","title":"Senior Tech Culture Editor","staff":true},"509873":{"name":"Beth Mole","title":"Health Reporter","staff":true},"335607":{"name":"Cyrus Farivar","title":"Senior Tech Policy Reporter","staff":true},"329388":{"name":"Dan Goodin","title":"Security Editor","staff":true},"512413":{"name":"Eric Berger","title":"Senior Space Editor","staff":true},"55943":{"name":"Jacqui Cheng","title":"Editor at Large","staff":false},"52979":{"name":"John Timmer","title":"Senior Science Editor","staff":true},"312082":{"name":"Jon Brodkin","title":"Senior IT Reporter","staff":true},"14317":{"name":"Jonathan M. Gitlin","title":"Automotive Editor","staff":true},"338374":{"name":"Kathleen DeVries","title":"","staff":false},"440179":{"name":"Kerry Staurseth","title":"Associate Copyeditor","staff":true},"328283":{"name":"Kyle Orland","title":"Senior Gaming Editor","staff":true},"331051":{"name":"Megan Geuss","title":"Staff editor","staff":true},"1169":{"name":"Peter Bright","title":"Technology Editor","staff":true},"391727":{"name":"Ron Amadeo","title":"Reviews Editor","staff":true},"348927":{"name":"Sam Machkovech","title":"Tech Culture Editor","staff":true},"588289":{"name":"Samuel Axon","title":"Senior Reviews Editor","staff":true},"314884":{"name":"Sean Gallagher","title":"IT Editor","staff":true},"495539":{"name":"S.I. Newhouse","title":"","staff":false},"173910":{"name":"Timothy B. Lee","title":"Senior tech policy reporter","staff":true},"505571":{"name":"Valentina Palladino","title":"Associate Reviewer","staff":true},"369205":{"name":"Akshat Rathi","title":"Associate Writer","staff":false},"325040":{"name":"Allie Wilkinson","title":"","staff":false},"332715":{"name":"Andrew Cunningham","title":"Reviews Editor Emeritus","staff":false},"505703":{"name":"Cassandra Khaw","title":"Contributing Reporter ","staff":false},"453791":{"name":"Cathleen O'Grady","title":"Contributing science reporter","staff":true},"102179":{"name":"Chris Lee","title":"Associate writer","staff":true},"332078":{"name":"Curt Hopkins","title":"Associate Writer","staff":false},"6978":{"name":"Dave Girard","title":"Associate Writer","staff":false},"332434":{"name":"Dave Klingler","title":"Associate Writer","staff":false},"129513":{"name":"David Kanter","title":"","staff":false},"254631":{"name":"Diana Gitig","title":"Associate Writer","staff":false},"52335":{"name":"edgar","title":"","staff":false},"172426":{"name":"egosumliber","title":"","staff":false},"480857":{"name":"Glyn Moody","title":"Contributing Policy Editor","staff":false},"46707":{"name":"Iljitsch van Beijnum","title":"Associate Writer","staff":false},"332336":{"name":"James Holloway","title":"Associate Writer","staff":false},"217531":{"name":"Jeremy Jacquot","title":"","staff":false},"15365":{"name":"Jeremy Reimer","title":"Senior Niche Technology Historian","staff":false},"4086":{"name":"Jim Salter","title":"Contributor","staff":false},"8996":{"name":"John Siracusa","title":"Associate writer","staff":false},"375641":{"name":"Kate Prengaman","title":"","staff":false},"251816":{"name":"Kate Shaw Yoshida","title":"Associate Writer","staff":false},"133411":{"name":"Knadles","title":"","staff":false},"37509":{"name":"Matt Ford","title":"Associate writer","staff":false},"300066":{"name":"Matthew Braga","title":"Associate writer","staff":true},"323078":{"name":"Matthew Francis","title":"Associate Writer","staff" ...
# </script>
# <article class="article-single standalone intro-standard " itemscope="" itemtype="http://schema.org/NewsArticle">
# <div class="column-wrapper">
# <div class="left-column">
# <header class="article-header">
# <h4 class="post-upperdek">
#       It explains the rains of Castamere    —
# </h4>
# <h1 itemprop="headline">This <em>Game of Thrones</em> climate model is what’s been missing from your life</h1>
# <h2 itemprop="description">“Samwell Tarly’s” tongue-in-cheek paper takes a swing at why winter is coming.</h2>
# <section class="post-meta">
# <p class="byline" itemprop="author creator" itemscope="" itemtype="http://schema.org/Person">
# <a href="https://arstechnica.com/author/scott-johnson/" itemprop="url" rel="author"><span itemprop="name">Scott K. Johnson</span></a>
#     -  <time class="date" data-time="1513898375" datetime="2017-12-21T23:19:35+00:00">Dec 21, 2017 11:19 pm UTC</time>
# </p>
# </section> </header>
# <section class="article-guts">
# <div class="article-content post-page" itemprop="articleBody">
# <figure class="intro-image intro-left">
# <img src="https://cdn.arstechnica.net/wp-content/uploads/2017/12/game_of_thrones_climate_model-3-800x414.jpg"/>
# <figcaption class="caption"><div class="caption-text"><a class="enlarge-link" data-height="619" data-width="1196" href="https://cdn.arstechnica.net/wp-content/uploads/2017/12/game_of_thrones_climate_model-3.jpg">Enlarge</a></div><div class="caption-credit"><a class="caption-link" href="http://www.bristol.ac.uk/news/2017/december/climate-game-of-thrones-.html" rel="nofollow">Dan Lunt, University of Bristol</a></div></figcaption> </figure>
# <aside id="social-left"><a class="comment-count icon-comment-bubble-down" href="https://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/?comments=1" title="50 posters participating, including story author.">
# <span class="comment-count-before">reader comments</span>
# <span class="comment-count-number">64</span>
# </a>
# <div class="share-links">
# <span>Share this story</span>
# <a class="social-icon share-facebook" href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Farstechnica.com%2F%3Fpost_type%3Dpost%26p%3D1236459" target="_blank" title="Share on Facebook"></a>
# <a class="social-icon share-twitter" href="https://twitter.com/share?text=This+%3Cem%3EGame+of+Thrones%3C%2Fem%3E+climate+model+is+what%E2%80%99s+been+missing+from+your+life&amp;url=https%3A%2F%2Farstechnica.com%2F%3Fpost_type%3Dpost%26p%3D1236459" target="_blank" title="Share on Twitter"></a>
# <a class="social-icon share-reddit" href="https://www.reddit.com/submit?url=https%3A%2F%2Farstechnica.com%2F%3Fpost_type%3Dpost%26p%3D1236459&amp;title=This+%3Cem%3EGame+of+Thrones%3C%2Fem%3E+climate+model+is+what%E2%80%99s+been+missing+from+your+life" target="_blank" title="Share on Reddit"></a>
# <a class="social-icon share-gplus" href="https://plus.google.com/share?url=https%3A%2F%2Farstechnica.com%2F%3Fpost_type%3Dpost%26p%3D1236459" target="_blank" title="Share on Google+"></a>
# </div>
# </aside>
# <!-- cache hit 158:single/related:42f36c5a4009c4b36e6fe08349345cea --><!-- empty -->
# <p>A central conceit of George R.R. Martin’s A Song of Ice and Fire books (and the popular HBO series <em>Game of Thrones</em> based on them) is that the seasons of the planet where they take place are not as predictable as the Earth’s annual cycle. Somehow the phrase “winter is coming” wouldn’t seem as foreboding if you could reply, “Yes, that usually happens in December through February.”</p>
# <p>But how could a planet have unruly seasons? Earth’s seasons are due to the tilt of its axis. During one part of Earth’s orbit, the Northern Hemisphere is tilted away from the Sun, with the resulting indirect sunlight spread thin over the surface of the hemisphere, causing winter. On the opposite side of its orbit, summer comes as this hemisphere is tilted toward direct sunlight. There isn’t much room in such clockwork for randomness.</p>
# <p>Well, if you’ve ever wanted to debate fan theories, here’s an excellent new resource for you to draw from: a real climate model simulation of Westeros and Essos.</p>
# <p>The <a href="http://www.bristol.ac.uk/news/2017/december/climate-game-of-thrones-.html">study</a> appears to have been published by one <a href="https://twitter.com/ClimateSamwell">Samwell Tarly</a>, who notes an affiliation to The Citadel in Oldtown—and also The University of Bristol in the UK. (The effort bears a frankly suspicious resemblance to a <a href="http://www.bristol.ac.uk/news/2013/10013.html">climate model</a> of Middle Earth created by a Radagast the Brown.) The new paper comprises what is apparently the very first issue of <em>The Philosophical Transactions of the Royal Society of King’s Landing</em>, a new journal that should not be confused with the long-lived (and nearly identically named) publication of the UK Royal Society. And yes, it is available in the languages of Dothraki and High Valyrian.</p>
# <p>The goal of this bit of fun was to see if there was a way to simulate Martin’s world by tweaking a climate model of the Earth. The author took some liberties to fill in the partial map of the “known world” in Martin’s books. And while fan explanations for Martin’s strange and long-lasting seasons have included wild variations of greenhouse gases to volcanic activity to ocean circulation patterns, the author finds these lacking, as there is at least one mention of shortened days during the long winter.</p>
# <p>That points to an orbital mechanism. The author’s idea is this: if the planet’s axis wobbled in a circle once per orbit, the summer hemisphere could stay pointed at its equivalent of the Sun the entire time. The first attempt to simulate this configuration crashed the model as intense winds developed between the hemispheres, which reached radically different temperatures. But reducing the planet’s tilt from 23.5 degrees to 10 degrees smoothed out the extremes.</p>
# <figure class="image shortcode-img center large" style="width:640px"><a alt="Model results for winter (top row) and summer (bottom row) showing temperature on the left and precipitation on the right." class="enlarge" data-height="1585" data-width="1226" href="https://cdn.arstechnica.net/wp-content/uploads/2017/12/game_of_thrones_climate_model-6.jpg"><img alt="Model results for winter (top row) and summer (bottom row) showing temperature on the left and precipitation on the right." height="827" src="https://cdn.arstechnica.net/wp-content/uploads/2017/12/game_of_thrones_climate_model-6-640x827.jpg" srcset="https://cdn.arstechnica.net/wp-content/uploads/2017/12/game_of_thrones_climate_model-6.jpg 2x" width="640"/></a><figcaption class="caption"><div class="caption-text"><a class="enlarge-link" data-height="1585" data-width="1226" href="https://cdn.arstechnica.net/wp-content/uploads/2017/12/game_of_thrones_climate_model-6.jpg">Enlarge</a> <span class="sep">/</span> Model results for winter (top row) and summer (bottom row) showing temperature on the left and precipitation on the right.</div><div class="caption-credit"><a class="caption-link" href="http://www.bristol.ac.uk/news/2017/december/climate-game-of-thrones-.html" rel="nofollow">Dan Lunt, University of Bristol</a></div></figcaption></figure>
# <p>In a winter configuration, most of The North freezes, while much of the rest of Westeros actually stays pretty warm. And that’s especially true on the western side of the continent, which is warmed by ocean currents. During summer, on the other hand, only a small refuge north of The Wall stays frozen (a likely hibernation spot for White Walkers, the author notes. Warm, southern Westeros is bathed in tropical rain.</p>
# <p>Referencing some weather data for the “real” Earth—apparently discovered on some dusty shelf of The Citadel Library—the author also finds some close comparisons. The winter climate at The Wall, for example, is similar to northern Sweden and Norway. At Casterly Rock—home to the Lannister family—summer conditions are equivalent to parts of eastern China or Houston, Texas.</p>
# <p>There is, however, a major problem with this proposed explanation for long, unpredictable seasons. It seems to work pretty well for describing any single season, but needs a little <em>deus ex machina</em> to actually change from one season to another. There’s no good way to flip the odd orbital behavior that keeps one season locked in, leaving the young Tarly to posit “a passing comet or just the magic of the Seven.” How a suggestion like that slipped through peer review is unclear.</p>
# <p>What’s more, the paper notes instances of characters in Martin’s books of navigating by the stars—which would be difficult if the constellations in the sky were rotating in an annual circuit.</p>
# <p>At any rate, the paper also includes a measure of the <em>GoT</em> world’s sensitivity to changes in greenhouse gas concentrations. This is in response to reports of measured increases “likely due to the recent increase in dragon population in Essos, the deforestation of many regions associated with the increase in shipbuilding throughout Westeros and Essos, and the excessive use of wildfire.”</p>
# <p>The simulations show about 2.1 degrees Celsius of warming for a doubling of the greenhouse gas concentration. That’s slightly less than the roughly 3-degrees best estimate for Earth, but this simulation could only run for 100 years, whereas simulations of Earth typically require several centuries to reach equilibrium.</p>
# <p>Noting the potential impact of sea-level rise on King’s Landing, the author writes, “[A]s a climate scientist, I strongly encourage all the Kingdoms of our planet to reduce their emissions of carbon dioxide and seek alternative ‘renewable’ energy (such as windmills).”</p>
# <p>On a slightly more serious note, Tarly’s light-hearted experiment is meant to help illustrate the value of climate models. They allow us to investigate our current world, or Earth’s past or future, or even another planet entirely—fictional or not. And as for the physically unavoidable consequences of an increased concentration of greenhouse gases on this planet or any other, a Dothraki saying comes to mind: “It is known.”</p>
# </div>
# </section>
# <section class="inline-video" data-video-overlay-template-id="tmpl-5a340160148bb05431000005" title="The Greatest Leap, Episode 3: Triumph">
# <h3>Latest Ars Video <span>&gt;</span></h3>
# <div class="video-wrapper">
# <div class="video-thumbnail" style="background-image: url('https://dwgyu36up6iuz.cloudfront.net/heru80fdn/image/upload/c_fill,d_placeholder.jpg,fl_progressive,g_face,h_360,q_80,w_640/v1513635477/arstechnica_the-greatest-leap-episode-3-triumph.jpg');"></div>
# <div class="video-overlay"></div>
# </div>
# <div class="video-description">
# <h2>The Greatest Leap, Episode 3: Triumph</h2>
# <span>In honor of the 50th anniversary of the beginning of the Apollo Program, Ars Technica brings you an in depth look at the Apollo missions through the eyes of the participants.</span>
# </div>
# <div style="clear: both;"></div>
# <template id="tmpl-5a340160148bb05431000005" type="text/template">
# <figure class="video">
# <div class="wrapper">
# <div class="ars-video-container" data-video-id="5a340160148bb05431000005" data-video-params="[]"></div>
# </div>
# <figcaption class="caption"><div class="caption-text">The Greatest Leap, Episode 3: Triumph</div></figcaption> </figure>
# <h3>The Greatest Leap, Episode 3: Triumph</h3>
# <p class="excerpt">In honor of the 50th anniversary of the beginning of the Apollo Program, Ars Technica brings you an in depth look at the Apollo missions through the eyes of the participants.</p>
# </template>
# </section>
# </div>
# <div class="xrail">
# <div class="xrail-content">
# <aside class="ad ad_xrail ad_xrail_top" id="ad_xrail_top"></aside>
# <aside class="ad_native" id="ad_xrail_native"></aside>
# </div>
# </div>
# </div>
# <div class="column-wrapper">
# <div class="left-column">
# <!-- cache hit 158:single/author:092724736b81fd9e5f537d77b9643ca0 --><section class="article-author">
# <a class="author-photo" href="/author/scott-johnson" style="background-image:url('https://cdn.arstechnica.net/wp-content/uploads/2016/09/sj_2016_prof_450.jpg');"></a>
# <div class="author-bio">
# <section class="author-bio-top">
# <a class="author-name" href="/author/scott-johnson">Scott K. Johnson</a>
#       Scott is a hydrogeologist and educator who has been covering the geosciences for Ars since 2011.    </section>
# <section class="author-social">
# <strong>Email</strong> <a href="mailto:scott.johnson@arstechnica.com">scott.johnson@arstechnica.com</a>
# <span class="slashes">//</span>
# <strong>Twitter</strong> <a href="https://www.twitter.com/SJvatn" target="_blank">@SJvatn</a>
# </section>
# </div>
# </section>
# <aside id="social-footer">
# <a class="comment-count icon-comment-bubble-down" href="https://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/?comments=1" title="50 posters participating, including story author.">
# <span class="comment-count-before">reader comments</span>
# <span class="comment-count-number">64</span>
# </a>
# <div class="share-links">
# <span>Share this story</span>
# <a class="social-icon share-facebook" href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Farstechnica.com%2F%3Fpost_type%3Dpost%26p%3D1236459" target="_blank" title="Share on Facebook"></a>
# <a class="social-icon share-twitter" href="https://twitter.com/share?text=This+%3Cem%3EGame+of+Thrones%3C%2Fem%3E+climate+model+is+what%E2%80%99s+been+missing+from+your+life&amp;url=https%3A%2F%2Farstechnica.com%2F%3Fpost_type%3Dpost%26p%3D1236459" target="_blank" title="Share on Twitter"></a>
# <a class="social-icon share-reddit" href="https://www.reddit.com/submit?url=https%3A%2F%2Farstechnica.com%2F%3Fpost_type%3Dpost%26p%3D1236459&amp;title=This+%3Cem%3EGame+of+Thrones%3C%2Fem%3E+climate+model+is+what%E2%80%99s+been+missing+from+your+life" target="_blank" title="Share on Reddit"></a>
# <a class="social-icon share-gplus" href="https://plus.google.com/share?url=https%3A%2F%2Farstechnica.com%2F%3Fpost_type%3Dpost%26p%3D1236459" target="_blank" title="Share on Google+"></a>
# </div>
# </aside>
# </div>
# <div class="xrail">
# </div>
# </div>
# <div id="article-footer-wrap">
# <div class="row comments-row">
# <section id="comments-area">
# <a name="comments-bar"></a>
# <div id="comments-container"></div>
# <div class="thick-divide-bottom" id="comments-posting-container">
# <p id="reply">You must <a class="vote_login" href="https://arstechnica.com/civis/ucp.php?mode=login&amp;return_to/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/">login or create an account</a> to comment.</p>
# </div>
# <section>
# </section></section></div>
# <div class="prev-next-links">
# <a href="https://arstechnica.com/information-technology/2017/12/chinese-hackers-go-after-think-tanks-in-wave-of-more-surgical-strikes/" rel="prev"><span class="arrow">←</span> Previous story</a> <a href="https://arstechnica.com/tech-policy/2017/12/washington-state-comcast-was-even-more-deceptive-than-we-thought/" rel="next">Next story <span class="arrow">→</span></a></div> <footer id="article-footer">
# <div id="recommendations-footer">
# <aside id="story-recommendations">
# <div class="heading-column">
# <h3>Related Stories</h3>
# </div>
# <div class="rec-wrap" id="story-recs"></div>
# </aside>
# <aside id="sponsored-recommendations">
# <div class="heading-column">
# <h3>Sponsored Stories</h3>
# <a href="http://www.outbrain.com/what-is/default/en" target="_blank">Powered by <span class="icon outbrain-logo icon-logo-outbrain"></span></a>
# </div>
# <div id="outbrain-recs">
# </div>
# </aside>
# <aside id="latest-stories">
# <div class="heading-column">
# <h3>Today on Ars</h3>
# </div>
# <div class="rec-wrap" id="latest-recs"></div>
# </aside>
# </div>
# </footer>
# </div>
# </article>
# </div>
# <footer class="site-footer">
# <nav class="nav-footer">
# <section>
# <ul>
# <li><a href="/rss-feeds/">RSS Feeds</a></li>
# <li><a href="http://arstechnica.com/science/2017/12/there-is-now-a-climate-model-of-the-world-of-game-of-thrones/?view=mobile" rel="nofollow">View Mobile Site</a></li>
# <li><a href="/about-us/">About Us</a></li>
# </ul>
# </section>
# <section>
# <ul>
# <li><a href="/contact-us/">Contact Us</a></li>
# <li><a href="/staff-directory/">Staff</a></li>
# <li><a href="/advertise-with-us/">Advertise with us</a></li>
# <li><a href="/reprints/">Reprints</a></li>
# </ul>
# </section>
# </nav>
# <section class="footer-terms-logo">
# <div class="cn-logo">
# <a class="icon icon-logo-cn-us" href="http://condenast.com/" title="Visit Condé Nast"></a>
# </div>
# <div id="copyright-terms">
#   CNMN Collection<br/>
#   WIRED Media Group<br/>
#   Use of this Site constitutes acceptance of our <a href="http://www.condenast.com/privacy-policy" target="_blank">User Agreement</a> (effective 1/2/14) and <a href="http://www.condenast.com/privacy-policy#privacypolicy">Privacy Policy</a> (effective 1/2/14), and <a href="/amendment-to-conde-nast-user-agreement-privacy-policy/">Ars Technica Addendum (effective 5/17/2012)</a>. View our <a href="/affiliate-link-policy/">Affiliate Link Policy</a>. <a href="http://www.condenast.com/privacy-policy#privacypolicy-california">Your California Privacy Rights</a>. The material on this site may not be reproduced, distributed, transmitted, cached or otherwise used, except with the prior written <a href="https://www.condenast.com/reprints-permissions">permission of Condé Nast</a>.
# </div>
# </section> </footer>
# </div>
# <script src="https://cdn.arstechnica.net/wp-content/themes/ars/assets/js/main-645b016794.js" type="text/javascript"></script>
# <!-- cache hit 158:single/javascript-footer:42f36c5a4009c4b36e6fe08349345cea -->
# <script src="https://cdn.arstechnica.net/wp-content/themes/ars/assets/js/ars-7309851ac7.ads.us.js" type="text/javascript"></script>
# <!-- Google Analytics start -->
# <script type="text/javascript">
# 	var _gaq = _gaq || [];
#   _gaq.push(
#     ['_setAccount', 'UA-31997-1'],
#     ['_setCustomVar', 1, 'view', "grid"],
#     ['_setCustomVar', 2, 'theme', "light"],
#     ['_setCustomVar', 3, 'logged_in', "false"],
#     ['_setCustomVar', 4, 'show_comments', "false"],
#     ['_setCustomVar', 5, 'is_premier', "false"],
#     ['_trackPageview']
#   );
# 	(function() {
# 	  var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 	  ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 	  var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	})();
# 	</script>
# <!-- Google Analytics end -->
# <!-- Parse.ly start -->
# <script type="text/javascript">
#   (function(d) {
#     var site = "arstechnica.com",
#     b = d.body,
#     e = d.createElement("div");
#     e.innerHTML = '<span id="parsely-cfg" data-parsely-site="'+site+'"></span>';
#     e.id = "parsely-root";
#     e.style.display = "none";
#     b.appendChild(e);
#   })(document);
#
#   (function(s, p, d) {
#     var h=d.location.protocol, i=p+"-"+s,
#     e=d.getElementById(i), r=d.getElementById(p+"-root"),
#     u=h==="https:"?"d1z2jf7jlzjs58.cloudfront.net"
#       :"static."+p+".com";
#     if (e) return;
#     e = d.createElement(s); e.id = i; e.async = true;
#     e.src = h+"//"+u+"/p.js"; r.appendChild(e);
#   })("script", "parsely", document);
# 	</script>
# <!-- Parse.ly end -->
# <!-- Adobe Tag Mgr. -->
# <script src="//assets.adobedtm.com/6372cf21ef88ee60bc2977a4898dcb5c7945a212/satelliteLib-56a425e07376b6977c987d46ef46ba636a6e2036.js"></script>
# <script type="text/javascript">_satellite.pageBottom();</script>
# <script src="//s.skimresources.com/js/100098X1555750.skimlinks.js" type="text/javascript"></script>
# </body>
# </html>

# %%
page_paragraphs = parsed_page.find('section', {'class': 'article-guts'}).findAll('p')
paragraph_text = [paragraph.text for paragraph in page_paragraphs]
article_text = '\n'.join(paragraph_text)

# %%
print(article_text)
# Out:
# A central conceit of George R.R. Martin’s A Song of Ice and Fire books (and the popular HBO series Game of Thrones based on them) is that the seasons of the planet where they take place are not as predictable as the Earth’s annual cycle. Somehow the phrase “winter is coming” wouldn’t seem as foreboding if you could reply, “Yes, that usually happens in December through February.”
# But how could a planet have unruly seasons? Earth’s seasons are due to the tilt of its axis. During one part of Earth’s orbit, the Northern Hemisphere is tilted away from the Sun, with the resulting indirect sunlight spread thin over the surface of the hemisphere, causing winter. On the opposite side of its orbit, summer comes as this hemisphere is tilted toward direct sunlight. There isn’t much room in such clockwork for randomness.
# Well, if you’ve ever wanted to debate fan theories, here’s an excellent new resource for you to draw from: a real climate model simulation of Westeros and Essos.
# The study appears to have been published by one Samwell Tarly, who notes an affiliation to The Citadel in Oldtown—and also The University of Bristol in the UK. (The effort bears a frankly suspicious resemblance to a climate model of Middle Earth created by a Radagast the Brown.) The new paper comprises what is apparently the very first issue of The Philosophical Transactions of the Royal Society of King’s Landing, a new journal that should not be confused with the long-lived (and nearly identically named) publication of the UK Royal Society. And yes, it is available in the languages of Dothraki and High Valyrian.
# The goal of this bit of fun was to see if there was a way to simulate Martin’s world by tweaking a climate model of the Earth. The author took some liberties to fill in the partial map of the “known world” in Martin’s books. And while fan explanations for Martin’s strange and long-lasting seasons have included wild variations of greenhouse gases to volcanic activity to ocean circulation patterns, the author finds these lacking, as there is at least one mention of shortened days during the long winter.
# That points to an orbital mechanism. The author’s idea is this: if the planet’s axis wobbled in a circle once per orbit, the summer hemisphere could stay pointed at its equivalent of the Sun the entire time. The first attempt to simulate this configuration crashed the model as intense winds developed between the hemispheres, which reached radically different temperatures. But reducing the planet’s tilt from 23.5 degrees to 10 degrees smoothed out the extremes.
# In a winter configuration, most of The North freezes, while much of the rest of Westeros actually stays pretty warm. And that’s especially true on the western side of the continent, which is warmed by ocean currents. During summer, on the other hand, only a small refuge north of The Wall stays frozen (a likely hibernation spot for White Walkers, the author notes. Warm, southern Westeros is bathed in tropical rain.
# Referencing some weather data for the “real” Earth—apparently discovered on some dusty shelf of The Citadel Library—the author also finds some close comparisons. The winter climate at The Wall, for example, is similar to northern Sweden and Norway. At Casterly Rock—home to the Lannister family—summer conditions are equivalent to parts of eastern China or Houston, Texas.
# There is, however, a major problem with this proposed explanation for long, unpredictable seasons. It seems to work pretty well for describing any single season, but needs a little deus ex machina to actually change from one season to another. There’s no good way to flip the odd orbital behavior that keeps one season locked in, leaving the young Tarly to posit “a passing comet or just the magic of the Seven.” How a suggestion like that slipped through peer review is unclear.
# What’s more, the paper notes instances of characters in Martin’s books of navigating by the stars—which would be difficult if the constellations in the sky were rotating in an annual circuit.
# At any rate, the paper also includes a measure of the GoT world’s sensitivity to changes in greenhouse gas concentrations. This is in response to reports of measured increases “likely due to the recent increase in dragon population in Essos, the deforestation of many regions associated with the increase in shipbuilding throughout Westeros and Essos, and the excessive use of wildfire.”
# The simulations show about 2.1 degrees Celsius of warming for a doubling of the greenhouse gas concentration. That’s slightly less than the roughly 3-degrees best estimate for Earth, but this simulation could only run for 100 years, whereas simulations of Earth typically require several centuries to reach equilibrium.
# Noting the potential impact of sea-level rise on King’s Landing, the author writes, “[A]s a climate scientist, I strongly encourage all the Kingdoms of our planet to reduce their emissions of carbon dioxide and seek alternative ‘renewable’ energy (such as windmills).”
# On a slightly more serious note, Tarly’s light-hearted experiment is meant to help illustrate the value of climate models. They allow us to investigate our current world, or Earth’s past or future, or even another planet entirely—fictional or not. And as for the physically unavoidable consequences of an increased concentration of greenhouse gases on this planet or any other, a Dothraki saying comes to mind: “It is known.”

# %%
# text tokenization and parsing

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from string import punctuation

# %%
tokenized_sentences = sent_tokenize(article_text)
tokenized_words = word_tokenize(article_text.lower())

filter_list = stopwords.words('english') + list(punctuation) + ['’', "“", "”"]
filtered_words = [word for word in tokenized_words if word not in filter_list]

# %%
print(len(tokenized_words), len(filtered_words))
# Out:
# 1055 505

# %%
# extraction and summarization

# %%
from nltk.probability import FreqDist
from heapq import nlargest

# %%
word_frequency = FreqDist(filtered_words)
top_10_words = nlargest(10, word_frequency, key=word_frequency.get)

# %%
print(top_10_words)
print([word_frequency[word] for word in top_10_words])
# Out:
# ['earth', 'planet', 'climate', 'author', 'martin', 'seasons', 'winter', 'one', 'could', 'hemisphere']
# [8, 7, 6, 6, 5, 5, 5, 5, 4, 4]

# %%
def score_sentence(sentence):
    """
    Only score words that are present in the top 10 list
    """
    score_words = (word for word in word_tokenize(sentence.lower()) if word in top_10_words)
    return sum(word_frequency[word] for word in score_words)

# %%
scored_sentences = [(score_sentence(sentence), sentence) for sentence in tokenized_sentences]

# %%
print(scored_sentences)
# Out:
# [(0, 'A central conceit of George R.R.'), (25, 'Martin’s A Song of Ice and Fire books (and the popular HBO series Game of Thrones based on them) is that the seasons of the planet where they take place are not as predictable as the Earth’s annual cycle.'), (25, 'Somehow the phrase “winter is coming” wouldn’t seem as foreboding if you could reply, “Yes, that usually happens in December through February.”\nBut how could a planet have unruly seasons?'), (13, 'Earth’s seasons are due to the tilt of its axis.'), (26, 'During one part of Earth’s orbit, the Northern Hemisphere is tilted away from the Sun, with the resulting indirect sunlight spread thin over the surface of the hemisphere, causing winter.'), (4, 'On the opposite side of its orbit, summer comes as this hemisphere is tilted toward direct sunlight.'), (0, 'There isn’t much room in such clockwork for randomness.'), (6, 'Well, if you’ve ever wanted to debate fan theories, here’s an excellent new resource for you to draw from: a real climate model simulation of Westeros and Essos.'), (5, 'The study appears to have been published by one Samwell Tarly, who notes an affiliation to The Citadel in Oldtown—and also The University of Bristol in the UK.'), (14, '(The effort bears a frankly suspicious resemblance to a climate model of Middle Earth created by a Radagast the Brown.)'), (0, 'The new paper comprises what is apparently the very first issue of The Philosophical Transactions of the Royal Society of King’s Landing, a new journal that should not be confused with the long-lived (and nearly identically named) publication of the UK Royal Society.'), (0, 'And yes, it is available in the languages of Dothraki and High Valyrian.'), (19, 'The goal of this bit of fun was to see if there was a way to simulate Martin’s world by tweaking a climate model of the Earth.'), (11, 'The author took some liberties to fill in the partial map of the “known world” in Martin’s books.'), (26, 'And while fan explanations for Martin’s strange and long-lasting seasons have included wild variations of greenhouse gases to volcanic activity to ocean circulation patterns, the author finds these lacking, as there is at least one mention of shortened days during the long winter.'), (0, 'That points to an orbital mechanism.'), (21, 'The author’s idea is this: if the planet’s axis wobbled in a circle once per orbit, the summer hemisphere could stay pointed at its equivalent of the Sun the entire time.'), (0, 'The first attempt to simulate this configuration crashed the model as intense winds developed between the hemispheres, which reached radically different temperatures.'), (7, 'But reducing the planet’s tilt from 23.5 degrees to 10 degrees smoothed out the extremes.'), (5, 'In a winter configuration, most of The North freezes, while much of the rest of Westeros actually stays pretty warm.'), (0, 'And that’s especially true on the western side of the continent, which is warmed by ocean currents.'), (6, 'During summer, on the other hand, only a small refuge north of The Wall stays frozen (a likely hibernation spot for White Walkers, the author notes.'), (0, 'Warm, southern Westeros is bathed in tropical rain.'), (6, 'Referencing some weather data for the “real” Earth—apparently discovered on some dusty shelf of The Citadel Library—the author also finds some close comparisons.'), (11, 'The winter climate at The Wall, for example, is similar to northern Sweden and Norway.'), (0, 'At Casterly Rock—home to the Lannister family—summer conditions are equivalent to parts of eastern China or Houston, Texas.'), (5, 'There is, however, a major problem with this proposed explanation for long, unpredictable seasons.'), (5, 'It seems to work pretty well for describing any single season, but needs a little deus ex machina to actually change from one season to another.'), (5, 'There’s no good way to flip the odd orbital behavior that keeps one season locked in, leaving the young Tarly to posit “a passing comet or just the m ...

# %%
top_scores = set(sentence[0] for sentence in nlargest(7, scored_sentences))
article_summary = '\n'.join(sentence[1] for sentence in scored_sentences if sentence[0] in top_scores)

# %%
print(article_summary)
# Out:
# Martin’s A Song of Ice and Fire books (and the popular HBO series Game of Thrones based on them) is that the seasons of the planet where they take place are not as predictable as the Earth’s annual cycle.
# Somehow the phrase “winter is coming” wouldn’t seem as foreboding if you could reply, “Yes, that usually happens in December through February.”
# But how could a planet have unruly seasons?
# During one part of Earth’s orbit, the Northern Hemisphere is tilted away from the Sun, with the resulting indirect sunlight spread thin over the surface of the hemisphere, causing winter.
# And while fan explanations for Martin’s strange and long-lasting seasons have included wild variations of greenhouse gases to volcanic activity to ocean circulation patterns, the author finds these lacking, as there is at least one mention of shortened days during the long winter.
# The author’s idea is this: if the planet’s axis wobbled in a circle once per orbit, the summer hemisphere could stay pointed at its equivalent of the Sun the entire time.
# That’s slightly less than the roughly 3-degrees best estimate for Earth, but this simulation could only run for 100 years, whereas simulations of Earth typically require several centuries to reach equilibrium.
# Noting the potential impact of sea-level rise on King’s Landing, the author writes, “[A]s a climate scientist, I strongly encourage all the Kingdoms of our planet to reduce their emissions of carbon dioxide and seek alternative ‘renewable’ energy (such as windmills).”
# On a slightly more serious note, Tarly’s light-hearted experiment is meant to help illustrate the value of climate models.
